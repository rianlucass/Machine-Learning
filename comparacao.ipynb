# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
idh_df = pd.read_csv("dados/Human-Development-Index-concluido.csv")
suicidio_df = pd.read_csv("dados/suicide_statistic_concluido.csv")

# %%
suicidio_df['country'] = suicidio_df['country'].str.strip()

# %%
paises_disponiveis = sorted(suicidio_df['country'].unique())

# %%
print(paises_disponiveis)
# Out:
# ['Albania', 'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Bermuda', 'Bolivia', 'Bosnia and Herzegovina', 'Brazil', 'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria', 'Cabo Verde', 'Canada', 'Cayman Islands', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Estonia', 'Falkland Islands (Malvinas)', 'Fiji', 'Finland', 'France', 'French Guiana', 'Georgia', 'Germany', 'Greece', 'Grenada', 'Guadeloupe', 'Guatemala', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong SAR', 'Hungary', 'Iceland', 'Iran (Islamic Rep of)', 'Iraq', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia', 'Lithuania', 'Luxembourg', 'Macau', 'Malaysia', 'Maldives', 'Malta', 'Martinique', 'Mauritius', 'Mayotte', 'Mexico', 'Monaco', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Netherlands', 'Netherlands Antilles', 'New Zealand', 'Nicaragua', 'Norway', 'Occupied Palestinian Territory', 'Oman', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Republic of Korea', 'Republic of Moldova', 'Reunion', 'Rodrigues', 'Romania', 'Russian Federation', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Pierre and Miquelon', 'Saint Vincent and Grenadines', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia', 'Serbia', 'Seychelles', 'Singapore', 'Slovakia', 'Slovenia', 'South Africa', 'Spain', 'Sri Lanka', 'Suriname', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'TFYR Macedonia', 'Tajikistan', 'Thailand', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States of America', 'Uruguay', 'Uzbekistan', 'Venezuela (Bolivarian Republic of)', 'Virgin Islands (USA)', 'Zimbabwe']

# %%
paises = ["Norway", "Germany", "Brazil", "Mexico", "Mozambique", "Zimbabwe"]

# %%
idh_df['Country'] = idh_df['Country'].str.strip()
idh_filtrado = idh_df[idh_df['Country'].isin(paises)][['Country', 'Human Development Index (2021)']]

# %%
plt.figure(figsize=(10, 6))
plt.bar(idh_filtrado['Country'], idh_filtrado['Human Development Index (2021)'], color='green')
plt.title('IDH (2021) por País')
plt.xlabel('País')
plt.ylabel('IDH (2021)')
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
suicidio_df['country'] = suicidio_df['country'].str.strip()
suicidio_df = suicidio_df[suicidio_df['country'].isin(paises)]
suicidio_df['taxa_suicidio'] = (suicidio_df['suicides_no'] / suicidio_df['population']) * 100000
taxa_media = suicidio_df.groupby('country')['taxa_suicidio'].mean().reset_index()

# %%
plt.figure(figsize=(10, 6))
plt.bar(taxa_media['country'], taxa_media['taxa_suicidio'], color='orange')
plt.title('Taxa Média de Suicídio por País (por 100 mil habitantes)')
plt.xlabel('País')
plt.ylabel('Taxa média de suicídio')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
