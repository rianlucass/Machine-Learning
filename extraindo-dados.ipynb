# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_suicidio = pd.read_csv('dados/suicide_statistic_concluido.csv')
df_idh = pd.read_csv('dados/Human-Development-Index-concluido.csv')

# %%
paises = ['Chad', 'Mozambique', 'Brazil', 'India', 'Germany', 'Norway']

# %%
df_suicidio_paises = df_suicidio[df_suicidio['country'].isin(paises)]
df_idh_paises = df_idh[df_idh['Country'].isin(paises)]

# %%
df_suicidio_paises.head(10000)
# Out:
#       country  year     sex          age  suicides_no  population
# 6204   Brazil  1979  female  15-24 years        385.0  12448100.0
# 6205   Brazil  1979  female  25-34 years        227.0   8867900.0
# 6206   Brazil  1979  female  35-54 years        269.0  10282200.0
# 6207   Brazil  1979  female   5-14 years         47.0  14135000.0
# 6208   Brazil  1979  female  55-74 years        121.0   4678800.0
# ...       ...   ...     ...          ...          ...         ...
# 28267  Norway  2015    male  25-34 years         64.0    361373.0
# 28268  Norway  2015    male  35-54 years        140.0    736827.0
# 28269  Norway  2015    male   5-14 years          2.0    320375.0
# 28270  Norway  2015    male  55-74 years        119.0    544268.0
# 28271  Norway  2015    male    75+ years         32.0    146511.0
#
# [1200 rows x 6 columns]

# %%
df_idh_paises.head()
# Out:
#         Country  Human Development Index (1990)  \
# 23       Brazil                           0.610
# 44      Germany                           0.829
# 78        India                           0.434
# 119  Mozambique                           0.238
# 129      Norway                           0.838
#
#      Human Development Index (1991)  Human Development Index (1992)  \
# 23                            0.616                           0.622
# 44                            0.835                           0.842
# 78                            0.437                           0.442
# 119                           0.240                           0.234
# 129                           0.845                           0.851
#
#      Human Development Index (1993)  Human Development Index (1994)  \
# 23                            0.630                           0.638
# 44                            0.852                           0.858
# ...

# %%
df_suicidio_paises.to_csv('analise/suicidio_filtrado.csv', index=False)
df_idh_paises.to_csv('analise/idh_filtrado.csv', index=False)
